# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
data1=pd.read_csv("happiness_index.csv")

# %%
data1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data1.drop(['Region','Country'],axis='columns',inplace=True)

# %%
data1
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
data1.isnull().sum()
# Out:
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data2=data1.head(10)

# %%
data2
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587         0.03411                   1.39651
# 1               2            7.561         0.04884                   1.30232
# 2               3            7.527         0.03328                   1.32548
# 3               4            7.522         0.03880                   1.45900
# 4               5            7.427         0.03553                   1.32629
# 5               6            7.406         0.03140                   1.29025
# 6               7            7.378         0.02799                   1.32944
# 7               8            7.364         0.03157                   1.33171
# 8               9            7.286         0.03371                   1.25018
# 9              10            7.284         0.04083                   1.33358
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
data2.columns
# Out:
# Index(['Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
sns.lineplot(x=data2["Freedom"],y=data2["Happiness Score"],data=data2)
plt.show()
#the below graph shows that Happiness Score increases with Freedom

# %%
sns.lineplot(x=data2["Economy (GDP per Capita)"],y=data2["Happiness Score"],data=data2)
plt.show()
#the below graph shows that Economy and Happiness Score depends upone each other

# %%
sns.lineplot(x=data2["Trust (Government Corruption)"],y=data2["Happiness Score"],data=data2)
plt.show()
#the below graph shows that countries with less corruption are likely to be getting high Happiness Score

# %%
# correlation heatmap
corr_hmap=data.corr()
plt.figure(figsize=(7,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
data1
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(data1))
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
data_new=data1[(z<3).all(axis=1)]

# %%
print(data1.shape)
print(data_new.shape)
# Out:
# (158, 10)
# (149, 10)

# %%
data=data_new
data.shape
# Out:
# (149, 10)

# %%
data.skew()
# Out:
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
for col in data.columns:
    if data.skew().loc[col]>0.55:
        data[col]=np.log1p(data[col])

# %%
data.skew()
# Out:
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.193808
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.095190
# Generosity                       0.433539
# Dystopia Residual               -0.021144
# dtype: float64

# %%
data1=data.drop(columns=['Happiness Rank'])
x=data1
y=data['Happiness Rank']

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import train_test_split
max_r_score=0
for r_state in range(37,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to 39 is 0.9928262143423776

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=39,test_size=0.20)
lreg=linear_model.LinearRegression()
lreg.fit(x_train,y_train)
y_pred=lreg.predict(x_test)

# %%
print("r2 score is:",r2_score(y_test,y_pred))
print("RMSE is:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is: 0.9928262143423776
# RMSE is: 4.043011365603236

# %%
#cross validation
from sklearn.model_selection import cross_val_score

lrscores=cross_val_score(lreg,x,y,cv=5)
print(lrscores)
print(lrscores.mean(),lrscores.std())
# Out:
# [-1.07686583  0.34496399  0.6052727   0.62666683  0.30619879]
# 0.16124729485483372 0.6326864601576305

# %%
 import joblib
joblib.dump(lreg,'Happiness_index.pkl')
# Out:
# ['Happiness_index.pkl']
